# %%
# Loading up the script from the source folder.
from source.clusters_analysis import cluster_analysis

# In this analysis, we will choose subject number 7.
cluster_test = cluster_analysis(subject_id = 7)
# Out:
# > 7/7 packages are installed:
# pandas package is Installed (v2.2.3)
# numpy package is Installed (v2.1.3)
# scipy package is Installed (v1.14.1)
# tqdm package is Installed (v4.67.0)
# pandarallel package is Installed (v1.6.5)
# sqlalchemy package is Installed (v2.0.45)
# pymysql package is Installed (v1.1.1)

# %%
# Let's get information about the cells whitin node `99132` (for example).
node_cells = cluster_test.lookup_node(node_id = 99132)
node_cells
# Out:
#                       sp_cluster  \
# WMGMINPRGGSTINAEKFQG       99132
# GQRPDWTGIINPSGGSTSYA       99132
# MGIISPRGGSTSYAEKFQGR       99132
# WMGIISPRGGSTSYAEKFQG       99132
#
#                                                                 sp_path  \
# WMGMINPRGGSTINAEKFQG  99132/99131/99130/99102/98890/98626/95580/9079...
# GQRPDWTGIINPSGGSTSYA  99132/99131/99130/99102/98890/98626/95580/9079...
# MGIISPRGGSTSYAEKFQGR  99132/99131/99130/99102/98890/98626/95580/9079...
# WMGIISPRGGSTSYAEKFQG  99132/99131/99130/99102/98890/98626/95580/9079...
#
#                         ab_target time_point
# WMGMINPRGGSTINAEKFQG  Non-Spike B    4 weeks
# GQRPDWTGIINPSGGSTSYA  Non-Spike B    4 weeks
# MGIISPRGGSTSYAEKFQGR  Non-Spike B    2 weeks
# WMGIISPRGGSTSYAEKFQG  Non-Spike B    2 weeks

# %%
# Now let's visualize the cell count via pie chart - focus on "time_point" column.
cluster_test.plot_node(node_id = 99132,
                       by = "time_point")
